# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## Write some markdown to explain that this notebook will be mainly used for the capstone project.
#
# ### This notebook will be mainly used for Capstone Project, In this project we I will used all of that I have learned. In the beginning of this course, Markdown is the first lesson I have immediately learned upon creating this Notebook.
# #### Import the pandas library as pd.
# ##### Import the Numpy library as np.
# ###### Print the following the statement: Hello Capstone Project Course!

# %%
import pandas as pd

# %%
import numpy as np

# %%
A = 'Hello Capstone Project Course!'

# %%
print(A)
# Out:
# Hello Capstone Project Course!
